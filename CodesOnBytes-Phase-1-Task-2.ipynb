# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import os

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'Untitled.ipynb', 'Untitled1.ipynb']

# %%
df = pd.read_csv("E:\dataset - netflix1.csv")

# %%
df.shape
# Out:
# (8790, 10)

# %%
df
# Out:
#      Movie_id     type                                  title  \
# 0          s1    Movie                   Dick Johnson Is Dead
# 1          s3  TV Show                              Ganglands
# 2         s10    Movie                           The Starling
# 3        s100  TV Show                           On the Verge
# 4       s1000    Movie                               Stowaway
# ...       ...      ...                                    ...
# 8785     s995    Movie                  This Lady Called Life
# 8786     s996    Movie                              Vizontele
# 8787     s997    Movie                             HOMUNCULUS
# 8788     s998  TV Show  Life in Color with David Attenborough
# 8789     s999    Movie                   Searching For Sheela
#
#                               director         country  date_added  \
# 0                      Kirsten Johnson   United States   9-25-2021
# 1                      Julien Leclercq          France   9-24-2021
# 2                       Theodore Melfi   United States   9/24/2021
# 3                            Not Given          France  09-07-2021
# 4                            Joe Penna         Germany   4/22/2021
# ...                                ...             ...         ...
# 8785                      Kayode Kasum         Nigeria   4/23/2021
# 8786  Yılmaz Erdoğan, Ömer Faruk Sorak          Turkey   4/23/2021
# 8787                   Takashi Shimizu           Japan   4/22/2021
# 8788               Alastair Fothergill  United Kingdom   4/22/2021
# 8789                         Not Given           India   4/22/2021
#
#       release_year rating  duration  \
# 0             2020  PG-13    90 min
# 1             2021  TV-MA  1 Season
# 2             2021  PG-13   104 min
# 3             2021  TV-MA  1 Season
# 4             2021  TV-MA   116 min
# ...            ...    ...       ...
# 8785          2020  TV-14   120 min
# 8786          2001  TV-MA   106 min
# 8787          2021  TV-MA   116 min
# 8788          2021  TV-PG  1 Season
# 8789          2021  TV-14    58 min
#
#                                               listed_in
# 0                                         Documentaries
# 1     Crime TV Shows, International TV Shows, TV Act...
# 2                                      Comedies, Dramas
# 3                                TV Comedies, TV Dramas
# 4               Dramas, International Movies, Thrillers
# ...                                                 ...
# 8785      Dramas, International Movies, Romantic Movies
# 8786             Comedies, Dramas, International Movies
# 8787     Horror Movies, International Movies, Thrillers
# 8788  British TV Shows, Docuseries, International TV...
# 8789                Documentaries, International Movies
#
# [8790 rows x 10 columns]

# %%
df.columns
# Out:
# Index(['Movie_id', 'type', 'title', 'director', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Movie_id      8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   object
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 686.8+ KB

# %%
df.describe()
# Out:
#        release_year
# count   8790.000000
# mean    2014.183163
# std        8.825466
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
# checking missing values
df.isnull().sum()
# Out:
# Movie_id        0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
df.isnull().any()
# Out:
# Movie_id        False
# type            False
# title           False
# director        False
# country         False
# date_added      False
# release_year    False
# rating          False
# duration        False
# listed_in       False
# dtype: bool

# %%
sns.heatmap(df.isnull(), yticklabels=False)
# Out:
# <Axes: >

# %%
df.dropna()
# Out:
#      Movie_id     type                                  title  \
# 0          s1    Movie                   Dick Johnson Is Dead
# 1          s3  TV Show                              Ganglands
# 2         s10    Movie                           The Starling
# 3        s100  TV Show                           On the Verge
# 4       s1000    Movie                               Stowaway
# ...       ...      ...                                    ...
# 8785     s995    Movie                  This Lady Called Life
# 8786     s996    Movie                              Vizontele
# 8787     s997    Movie                             HOMUNCULUS
# 8788     s998  TV Show  Life in Color with David Attenborough
# 8789     s999    Movie                   Searching For Sheela
#
#                               director         country  date_added  \
# 0                      Kirsten Johnson   United States   9-25-2021
# 1                      Julien Leclercq          France   9-24-2021
# 2                       Theodore Melfi   United States   9/24/2021
# 3                            Not Given          France  09-07-2021
# 4                            Joe Penna         Germany   4/22/2021
# ...                                ...             ...         ...
# 8785                      Kayode Kasum         Nigeria   4/23/2021
# 8786  Yılmaz Erdoğan, Ömer Faruk Sorak          Turkey   4/23/2021
# 8787                   Takashi Shimizu           Japan   4/22/2021
# 8788               Alastair Fothergill  United Kingdom   4/22/2021
# 8789                         Not Given           India   4/22/2021
#
#       release_year rating  duration  \
# 0             2020  PG-13    90 min
# 1             2021  TV-MA  1 Season
# 2             2021  PG-13   104 min
# 3             2021  TV-MA  1 Season
# 4             2021  TV-MA   116 min
# ...            ...    ...       ...
# 8785          2020  TV-14   120 min
# 8786          2001  TV-MA   106 min
# 8787          2021  TV-MA   116 min
# 8788          2021  TV-PG  1 Season
# 8789          2021  TV-14    58 min
#
#                                               listed_in
# 0                                         Documentaries
# 1     Crime TV Shows, International TV Shows, TV Act...
# 2                                      Comedies, Dramas
# 3                                TV Comedies, TV Dramas
# 4               Dramas, International Movies, Thrillers
# ...                                                 ...
# 8785      Dramas, International Movies, Romantic Movies
# 8786             Comedies, Dramas, International Movies
# 8787     Horror Movies, International Movies, Thrillers
# 8788  British TV Shows, Docuseries, International TV...
# 8789                Documentaries, International Movies
#
# [8790 rows x 10 columns]

# %%
df.tail()
# Out:
#      Movie_id     type                                  title  \
# 8785     s995    Movie                  This Lady Called Life
# 8786     s996    Movie                              Vizontele
# 8787     s997    Movie                             HOMUNCULUS
# 8788     s998  TV Show  Life in Color with David Attenborough
# 8789     s999    Movie                   Searching For Sheela
#
#                               director         country date_added  \
# 8785                      Kayode Kasum         Nigeria  4/23/2021
# 8786  Yılmaz Erdoğan, Ömer Faruk Sorak          Turkey  4/23/2021
# 8787                   Takashi Shimizu           Japan  4/22/2021
# 8788               Alastair Fothergill  United Kingdom  4/22/2021
# 8789                         Not Given           India  4/22/2021
#
#       release_year rating  duration  \
# 8785          2020  TV-14   120 min
# 8786          2001  TV-MA   106 min
# 8787          2021  TV-MA   116 min
# 8788          2021  TV-PG  1 Season
# 8789          2021  TV-14    58 min
#
#                                               listed_in
# 8785      Dramas, International Movies, Romantic Movies
# 8786             Comedies, Dramas, International Movies
# 8787     Horror Movies, International Movies, Thrillers
# 8788  British TV Shows, Docuseries, International TV...
# 8789                Documentaries, International Movies

# %%
# Visualize the distribution of numerical features before  removing outliers

numerical_columns = df.select_dtypes(include=[np.number]).columns

# Visualize the distribution of numerical features
for col in numerical_columns:
    plt.figure(figsize=(8, 5))
    sns.histplot(df[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.show()

# %%
# Remove outliers using z-score
from scipy.stats import zscore

z_scores = zscore(df.select_dtypes(include=[np.number]))
abs_z_scores = np.abs(z_scores)
filtered_entries = (abs_z_scores < 3).all(axis=1)
df = df[filtered_entries]

# %%
# visualize the distribution of numerical features after removing outliers
num_cols = df.select_dtypes(include=[np.number]).columns
for col in num_cols:
    plt.figure(figsize=(8, 5))
    sns.histplot(df[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.show()

# %%
# Save the cleaned dataset
df.to_csv('netflix_cleaned_dataset.csv', index=False)
