# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = r"E:\CodesonBytes\dataset - netflix1.csv"
data = pd.read_csv(file_path)
data
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %%
df = pd.DataFrame(data)
df
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %%
data.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
data.tail()
# Out:
#      show_id     type               title   director        country  \
# 8785   s8797  TV Show          Yunus Emre  Not Given         Turkey
# 8786   s8798  TV Show           Zak Storm  Not Given  United States
# 8787   s8801  TV Show  Zindagi Gulzar Hai  Not Given       Pakistan
# 8788   s8784  TV Show                Yoko  Not Given       Pakistan
# 8789   s8786  TV Show                 YOM  Not Given       Pakistan
#
#       date_added  release_year rating   duration  \
# 8785   1/17/2017          2016  TV-PG  2 Seasons
# 8786   9/13/2018          2016  TV-Y7  3 Seasons
# 8787  12/15/2016          2012  TV-PG   1 Season
# 8788   6/23/2018          2016   TV-Y   1 Season
# 8789    6/7/2018          2016  TV-Y7   1 Season
#
#                                               listed_in
# 8785                  International TV Shows, TV Dramas
# 8786                                           Kids' TV
# 8787  International TV Shows, Romantic TV Shows, TV ...
# ...

# %%
data.shape
# Out:
# (8790, 10)

# %%
data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in'],
#       dtype='object')

# %%
data.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# dtype: object

# %%
data.describe()
# Out:
#        release_year
# count   8790.000000
# mean    2014.183163
# std        8.825466
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Finding missing values

# %%
data.isna().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ### 1. Find the frequency of 'type' of genre has released ?

# %%
type_counts = data['type'].value_counts()
type_counts
# Out:
# type
# Movie      6126
# TV Show    2664
# Name: count, dtype: int64

# %%
# create a pie chart
plt.pie(type_counts, labels = type_counts.index,autopct='%1.1f%%', startangle=90)
# Equal aspect ratio ensures that pie is drawn as a circle.
plt.axis('equal')  

# Display the plot
plt.show()

# %% [markdown]
# #### The frequency of movies released is more than that of TV Show

# %% [markdown]
# ### 2. Shows released based on 'Country'

# %%
country_values = data[data['country']!='Not Given']
country_values = country_values['country'].value_counts()
c_v = country_values[:10]

# %%
# create a bar plot
plt.bar(c_v.index, c_v.values)

# Labeling
plt.title('Frequency of shows across top 10 countries')
plt.xlabel('Country')
plt.ylabel('Frequency')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ## 3. Top 10 directors

# %%
# Assuming 'director' is another categorical column
data_directors = data[data['director']!='Not Given']
directors = data_directors['director']

# Plotting the top 10 directors
plt.figure(figsize=(10, 8))
directors.value_counts().head(10).plot(kind='bar', color='lightgreen')
plt.title('Top 10 Directors', fontsize=18)
plt.xlabel('Director', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.show()

# %%
numerical_columns = df.select_dtypes(include=[np.number]).columns

# Visualize the distribution of numerical features using box plots
for col in numerical_columns:
    plt.figure(figsize=(8, 5))
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot of {col}')
    plt.show()

# %%
numerical_columns = df.select_dtypes(include=[np.number]).columns

# Visualize the distribution of numerical features
for col in numerical_columns:
    plt.figure(figsize=(8, 5))
    sns.histplot(df[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.show()

# %%
# Assuming 'rating' is another categorical column
ratings = df['rating'].value_counts()
plt.figure(figsize=(12,6))
sns.barplot(x=ratings.index,  y= ratings.values)
plt.title('Top ratings of genres')
plt.xlabel('rating')
plt.ylabel('count')
plt.show()

# %%
# Top 10 genres:
genres = df['listed_in'].str.split(', ', expand=True).stack()

# Plotting the top 10 genres
plt.figure(figsize=(10, 8))
genres.value_counts().head(10).plot(kind='bar', color='skyblue')
plt.title('Top 10 Genres', fontsize=18)
plt.xlabel('Genre', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.show()

# %%
# Count of Ratings by Movies and Shows
new_catgs = {
    'TV-PG': 'Parental Guidance',
    'TV-MA': 'Mature Audience',
    'TV-Y7-FV': 'Teens',
    'TV-Y7': 'Teens',
    'TV-14': 'Teens',
    'R': 'Mature Audience',
    'TV-Y': 'General Audience',
    'NR': 'Mature Audience',
    'PG-13': 'Teens',
    'TV-G': 'General Audience',
    'PG': 'Teens',
    'G': 'General Audience',
    'UR': 'Mature Audience',
    'NC-17': 'Mature Audience'
}

df['rating'] = df['rating'].replace(new_catgs)

plt.figure(figsize=(10, 6))

# Plotting the count of Rating by Movies and Shows
sns.countplot(x="rating", data=df, palette="pastel", order=df['rating'].value_counts().index)

plt.title("Count of Ratings by Movies and Shows")
plt.xlabel("Rating")
plt.ylabel("Count")
plt.show()

# %%
# Number of Movies and TV Shows Released by Year (Top 15 Years)
df_15 = df.groupby(['type', 'release_year']).size().unstack().transpose().fillna(0).sort_values(by='release_year', ascending=False)

# Plotting the top 25 years with a stacked bar plot
df_15.head(15).plot.bar(stacked=True, figsize=(17, 12))

plt.title('Number of Movies and TV Shows Released by Year (Top 15 Years)')
plt.xlabel('Year')
plt.ylabel('Number of Content')
plt.show()

# %%
# Monthly Release Patterns Over the Years
df['date_added'] = pd.to_datetime(df['date_added'])  # Convert 'date_added' to datetime
df['month'] = df['date_added'].dt.month_name()
df['year'] = df['date_added'].dt.year

# Group by year and month and create a heatmap
df_h = df.groupby(['year', 'month']).size().unstack().fillna(0)
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

plt.figure(figsize=(15, 10))
sns.heatmap(df_h[month_order], cmap='coolwarm', annot=True, fmt='g', cbar_kws={'label': 'Number of Releases'})
plt.title('Monthly Release Patterns Over the Years')
plt.show()

# %%
# Release Years in India for the Last Decade
last_decade_data_india = df[(df['country'] == 'India') & (data['release_year'] >= 2010)]['release_year'].value_counts().sort_index()

plt.figure(figsize=(10, 6))
sns.lineplot(x=last_decade_data_india.index, y=last_decade_data_india.values, marker='o', color='red')
plt.title('Release Years in India for the Last Decade')
plt.xlabel('Release Year')
plt.ylabel('Number of Releases')
plt.show()
